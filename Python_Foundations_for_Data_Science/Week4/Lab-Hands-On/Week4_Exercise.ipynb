# %% [markdown]
# # **Problem 1 (Student Grade Analytics System)**
#
# ## Scenario
# You are building an academic reporting module for a university course.
# Each student has multiple grades stored in a dictionary. Your task is to design a **modular program** that calculates averages, assigns letter grades, and generates a structured report.
#
# ```python
# students = {
#     "Alice": [85, 90, 78],
#     "Bob": [70, 88, 92],
#     "Charlie": [95, 100, 93],
#     "Diana": [60, 75, 72]
# }
# ```
# ## Tasks
#
# ### **1. Write a Function to Calculate the Average**
# Create:
#
# ```python
# calculate_average(grades)
# ```
#
# **Requirements:**
# - Accepts a list of numbers.
# - Returns the average.
# - Must not print inside the function.
#
#
# ### **2. Write a Function to Assign a Letter Grade**
# Create:
#
# ```python
# assign_letter_grade(average, passing_mark=60)
# ```
#
# **Requirements:**
# - Uses a default parameter `passing_mark=60`.
# - Returns:
#   - A if average ≥ 90
#   - B if average ≥ 80
#   - C if average ≥ 70
#   - D if average ≥ passing_mark
#   - F otherwise
#
#
#
# ### **3. Write a Report Generator**
# Create:
#
# ```python
# generate_report(student_dict)
# ```
#
# **Requirements:**
# - Uses the previous two functions.
# - Returns a new dictionary structured as:
#
# ```python
# {
#     "Alice": {"average": 84.33, "grade": "B"},
#     ...
# }
# ```
#
# ### **4. Sorting Requirement**
# Sort students by average (highest first).
#
# ### **5. Structure Requirement**
# - Define all functions first.
# - Create a `main()` function.
# - Do not rely on global variables inside functions.
# ---

# %% [markdown]
# # **Problem 2 (Expense Tracker Module)**
#
# ## Scenario
# You are designing a reusable expense tracking module.
#
# ```python
# expenses = {
#     "January": [120, 340, 560],
#     "February": [400, 150],
#     "March": [800, 200, 100]
# }
# ```
#
# ## Tasks
#
# ### **1. Monthly Total Function**
# Create:
#
# ```python
# monthly_total(expense_list)
# ```
#
# - Returns total expenses for a month.
#
#
# ### **2. Highest Spending Month**
# Create:
#
# ```python
# highest_month(expense_dict)
# ```
#
# - Returns the month with the highest total spending.
#
#
# ### **3. Expense Filter**
# Create:
#
# ```python
# filter_expenses(expense_list, threshold=300)
# ```
#
# - Returns expenses above threshold.
# - Use list comprehension.
#
#
#
# ### **4. Program Structure**
# - Create a `main()` function.
# - Print total per month.
# - Print highest month.
# - Print filtered expenses.
# - Do not use global variables inside functions.
# ---

# %% [markdown]
# # **Problem 3 (Inventory Restocking System)**
#
# ## Scenario
# A store maintains product stock and the minimum required quantities.
#
# ```python
# inventory = {
#     "Apples": {"quantity": 20, "min_required": 25},
#     "Bananas": {"quantity": 40, "min_required": 30},
#     "Oranges": {"quantity": 15, "min_required": 20}
# }
# ```
# ## Tasks
#
# ### **1. Restock Check**
# Create:
#
# ```python
# needs_restock(product_info)
# ```
#
# - Returns True if quantity < min_required.
#
#
#
# ### **2. Restock Amount**
# Create:
#
# ```python
# restock_amount(product_info)
# ```
#
# - Returns the number of items required to reach minimum stock.
#
#
#
# ### **3. Generate Restock Report**
# Create:
#
# ```python
# generate_restock_report(inventory)
# ```
#
# - Returns dictionary of products needing restock:
#
# ```python
# {"Apples": 5, "Oranges": 5}
# ```
#
# ### **4. Sorting**
# - Sort report by highest restock amount.
# - Use lambda expression inside `sorted()`.
#
#   **Hint:** Use `sorted()` with a `lambda` to sort by values in a dictionary:
#
# ```python
# # Example syntax
# sorted(restock_report.items(), key=lambda x: x[1], reverse=True)
# ```
#
# - `x[1]` → accesses the restock amount (value) of each `(product, amount)` pair
# - `reverse=True` → sorts from highest to lowest
# - The result will be a **list of tuples** in descending restock order
# ---

# %% [markdown]
# # **Problem 4 (Voting Analysis with Sets)**
#
# ## Scenario
# Two polling stations collected votes:
#
# ```python
# station_A = {"Alice", "Bob", "Charlie", "Diana"}
# station_B = {"Charlie", "Diana", "Edward"}
# ```
#
# ## Tasks
#
# ### **1. Common Voters**
# Create:
#
# ```python
# common_voters(A, B)
# ```
#
# - Return voters appearing in both sets.
#
#
#
# ### **2. Unique Voters**
# Create:
#
# ```python
# unique_voters(A, B)
# ```
#
# - Return voters appearing in only one set.
#
#
#
# ### **3. All Voters**
# Create:
#
# ```python
# all_voters(A, B)
# ```
#
# - Return union of voters.
#
#
#
# ### **4. Turnout Analysis**
# Create:
#
# ```python
# analyse_turnout(A, B)
# ```
#
# - Return dictionary:
#
# ```python
# {
#     "total": ...,
#     "common": ...,
#     "unique": ...
# }
# ```
#
#
#
# ### **5. Sorting**
# - Sort voters alphabetically using `sorted()` and lambda.

# %% [markdown]
# ---
# # Final Mini Challenge: University Lab Submission Tracking System
#
# ## Scenario
#
# You are asked to implement a simple system that tracks student lab submissions for a university module. The system should clean the data, remove duplicate submissions, classify student engagement, compute weekly statistics, and present the results clearly.
#
# This challenge combines concepts from weeks 1, 2, 3, and 4:
#
# - control flow and logical reasoning
# - conditional statements and decision structures
# - comparison and logical operators
# - loops and iteration
# - basic list comprehensions
# - lists, tuples, dictionaries, and sets
# - nested data structures
# - functions, parameters, return values, and variable scope
# - default parameters
# - lambda expressions
# - reusable and modular code
#
# ## Given Data
#
# Each tuple contains:
#
# 1. a student ID
# 2. a student name
# 3. a list of submitted lab weeks
#
# Some students may have duplicate week entries. These duplicates should be removed during data cleaning.
#
# ```python
# submissions = [
#     ("S001", "Alice", ["Week1", "Week2", "Week2"]),
#     ("S002", "Bob", ["Week1"]),
#     ("S003", "Charlie", ["Week1", "Week2", "Week3"]),
#     ("S004", "Diana", []),
# ]
# ```

# %% [markdown]
# ## **Task 1: Data Cleaning and Modelling**
#
# Convert the given data into a dictionary with the following structure:
#
# ```python
# {
#     "S001": {
#         "name": "Alice",
#         "weeks": ["Week1", "Week2"],
#         "total_submissions": 2
#     }
# }
# ```
#
# Requirements:
#
# 1. use the student ID as the dictionary key
# 2. remove duplicate week entries using a set
# 3. sort the submitted weeks for consistent output
# 4. add a field called `total_submissions`
# 5. write comments explaining why a set and a dictionary are useful here

# %%
# Task 1: Write your solution here

cleaned_data = {}

# TODO: Loop through the submissions list
# TODO: Remove duplicate weeks
# TODO: Sort the weeks
# TODO: Store the cleaned information in cleaned_data

cleaned_data

# %% [markdown]
# ## **Task 2: Control Flow and Classification**
#
# Create a function called `classify_engagement(total_submissions)`.
#
# The function should return:
#
# - `"No Participation"` if the student submitted 0 weeks
# - `"Low"` if the student submitted 1 week
# - `"Moderate"` if the student submitted 2 weeks
# - `"High"` if the student submitted 3 or more weeks
#
# Then iterate through all students and print a report in this format:
#
# ```text
# Alice (S001): 2 submissions → Moderate
# ```

# %%
# Task 2: Write your solution here

def classify_engagement(total_submissions):
    # TODO: Add conditional statements here
    pass


# TODO: Loop through cleaned_data and print each student's engagement level

# %% [markdown]
# ## **Task 3: Weekly Submission Analytics**
#
# Create a dictionary that counts how many students submitted each week.
#
# Expected structure:
#
# ```python
# {
#     "Week1": 3,
#     "Week2": 2,
#     "Week3": 1
# }
# ```
#
# Then identify:
#
# - the most submitted week
# - the least submitted week

# %%
# Task 3: Write your solution here

week_counts = {}

# TODO: Count how many students submitted each week
# TODO: Identify the most submitted week
# TODO: Identify the least submitted week

# %% [markdown]
# ## **Task 4: Functions and Modular Programming**
#
# Refactor your solution into reusable functions.
#
# Create the following functions:
#
# 1. `clean_submissions(data)`
# 2. `compute_week_stats(data)`
# 3. `get_submission_summary(week_counts)`
#
# Requirements:
#
# - each function should receive input through parameters
# - each function should return a value
# - avoid relying on global variables
# - use local variables where appropriate

# %%
# Task 4: Write your solution here

def clean_submissions(data):
    # TODO: Return a cleaned dictionary of student submissions
    pass


def compute_week_stats(data):
    # TODO: Return a dictionary containing weekly submission counts
    pass


def get_submission_summary(week_counts):
    # TODO: Return the most submitted and least submitted weeks
    pass


# TODO: Test your functions here

# %% [markdown]
# ## **Task 5: List Comprehension**
#
# Create a list of students who submitted at least two weeks.
#
# Use a list comprehension.
#
# Expected output:
#
# ```python
# ["Alice", "Charlie"]
# ```

# %%
# Task 5: Write your solution here

active_students = []

# TODO: Replace the empty list with a list comprehension

active_students

# %% [markdown]
# ## **Task 6: Default Parameters**
#
# Write a function called `filter_students(data, min_weeks=2)`.
#
# The function should return the names of students who submitted at least `min_weeks` weeks.
#
# Test the function twice:
#
# 1. using the default value
# 2. using `min_weeks=3`

# %%
# Task 6: Write your solution here

def filter_students(data, min_weeks=2):
    # TODO: Return students who meet the minimum submission threshold
    pass


# TODO: Test the function using the default parameter
# TODO: Test the function using min_weeks=3

# %% [markdown]
# ## **Task 7: Lambda Expression**
#
# Sort students by the number of submissions in descending order.
#
# Use `sorted()` with a lambda expression.
#
# Example structure:
#
# ```python
# sorted_students = sorted(..., key=lambda item: ..., reverse=True)
# ```

# %%
# Task 7: Write your solution here

# TODO: Sort students by total_submissions in descending order

sorted_students = []

sorted_students

# %% [markdown]
# ## **Task 8: Nested Data Extension**
#
# Extend each student entry with a new field called `status`.
#
# Use the following rule:
#
# - students with two or more submissions are `"full-time"`
# - students with fewer than two submissions are `"part-time"`
#
# Then compute how many full-time and part-time students exist.

# %%
# Task 8: Write your solution here

status_counts = {
    "full-time": 0,
    "part-time": 0
}

# TODO: Add a status field to each student
# TODO: Count how many full-time and part-time students exist

status_counts

# %% [markdown]
# ## Reflection Questions
#
# **Answer the following questions as comments in the code cell below.**

# %%
# Reflection Question 1:
# Why is a dictionary more suitable than a list for this system?


# Reflection Question 2:
# What is the advantage of removing duplicates using a set?


# Reflection Question 3:
# How do functions improve code maintainability?


# Reflection Question 4:
# What is one limitation of this system design?


# Reflection Question 5:
# When should lambda expressions be avoided?

# %% [markdown]
# ------
# # Take-Home Assignments
# Complete the following problems at home. See the [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md).

# %% [markdown]
# # **Problem A (Data Cleaning Pipeline)**
#
# ## Scenario
# You are building a small data cleaning utility.
#
# ```python
# data = [12, -5, 30, None, 45, -2, 0, 18]
# ```
#
# ## Tasks
#
# ### 1. Remove Invalid Values
# Create:
#
# ```python
# remove_invalid(data_list)
# ```
#
# - Remove `None` values.
# - Return new list.
#
#
# ### 2. Remove Negatives
# Create:
#
# ```python
# remove_negatives(data_list)
# ```
#
# - Remove negative numbers.
# - Return new list.
#
# ### 3. Normalisation Function
# Create:
#
# ```python
# normalise(data_list, scale=100)
# ```
#
# - Divide each value by the maximum value.
# - Multiply by scale.
# - Return new list.
#
# ### 4. Cleaning Pipeline
# Create:
#
# ```python
# clean_pipeline(data)
# ```
#
# - Calls previous functions.
# - Returns cleaned and normalised data.
# - No global variables allowed.

# %% [markdown]
# # **Problem B (Bank Account Simulation)**
#
# ## Scenario
# You are implementing a simplified banking module.
#
# ```python
# accounts = {
#     "A101": 1200,
#     "A102": 540,
#     "A103": 3000
# }
# ```
#
#
#
# ## Tasks
#
# ### 1. Deposit Function
# Create:
#
# ```python
# deposit(accounts, acc_no, amount)
# ```
#
# - Update balance.
# - Return updated dictionary.
#
#
#
# ### 2. Withdraw Function
# Create:
#
# ```python
# withdraw(accounts, acc_no, amount)
# ```
#
# - Deduct amount if sufficient balance.
# - Return updated dictionary.
#
#
#
# ### 3. Apply Interest
# Create:
#
# ```python
# apply_interest(accounts, rate=0.03)
# ```
#
# - Add interest to all balances.
# - Use default parameter.
#
#
#
# ### 4. Rich Accounts Filter
# Create:
#
# ```python
# rich_accounts(accounts, threshold=1000)
# ```
#
# - Return dictionary of accounts above threshold.
# - Use dictionary comprehension.
#
#
# ### 5. Program Structure
# - Create `main()` function.
# - Call all functions sequentially.
# - Print intermediate results.

# %% [markdown]
# # **Problem C  (Ranking Job Applicants Using Lambda Expressions)**
# ## Scenario
#
# You are working as a data analyst in a recruitment team. The team receives multiple job applications and wants to rank candidates efficiently based on different criteria. Instead of writing multiple full functions, you are asked to use **lambda expressions** for concise, task-specific operations.
#
# The dataset contains basic information about each applicant, including their name, years of experience, and interview score.
#
# ## Given Data
#
# Each tuple contains:
# - name
# - years of experience
# - interview score
# ```python
# applicants = [
#     ("Alice", 3, 78),
#     ("Bob", 5, 85),
#     ("Charlie", 2, 65),
#     ("Diana", 4, 90),
#     ("Eve", 1, 70),
# ]
# ```
# ## Task 1: Sort by Interview Score
#
# Sort the applicants in **descending order** based on interview score.
#
# **Requirement:** use `sorted()` with a lambda expression.
#
# ## Task 2: Sort by Experience
#
# Sort the applicants in **ascending order** based on years of experience.
#
# ## Task 3: Multi-Criteria Sorting
#
# Sort applicants based on:
# 1. interview score (descending)
# 2. years of experience (descending)
#
# Hint: use a tuple inside the lambda expression.
#
# ## Task 4: Filter Strong Candidates
#
# Create a list of applicants who have a score greater than or equal to 80.
#
# **Requirement:** use `filter()` with a lambda expression and convert the result to a list.
#
# ## Task 5: Compute Weighted Score
#
# Define:
# `final_score = (0.6 * interview_score) + (0.4 * experience * 10)`
#
# Create a new list:
# `(name, final_score)`
#
# **Requirement:** use `map()` with a lambda expression.
#
# ## Task 6: Identify Top Candidate
#
# Using the computed final scores, identify the best candidate.
#
# **Requirement:** use `max()` with a lambda expression.
#
# ## Task 7: Convert to Dictionary
#
# Convert applicants into a dictionary:
# `{"Alice": 78, ...}`
#
# **Requirement:** use a lambda-based transformation approach.

# %% [markdown]
# ## Reflection Questions
#
# Answer the following as comments in the code below.

# %%
# Reflection Question 1:
# Why are lambda expressions useful in sorting operations?

# Reflection Question 2:
# What is a limitation of lambda expressions compared to normal functions?

# Reflection Question 3:
# When does using a lambda expression reduce readability?

# Reflection Question 4:
# Why is it important to keep lambda expressions simple?

# %% [markdown]
# ### Well done, Week 4 Exercises Complete 🎉!
#
# - Don't forget to submit your [exercise notebook](Week4_Exercise.ipynb) on your private GitHub Repository (see [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md)). The deadline is 14.05.2026 @ 23:59.
#
# - See you next time when we dive into `Files & Input/Output`!
