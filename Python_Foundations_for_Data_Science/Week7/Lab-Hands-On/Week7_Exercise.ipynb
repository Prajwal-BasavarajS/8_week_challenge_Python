# %% [markdown]
# ## **Problem 1 (Visualising Business Performance)**
#
# ## Scenario
# You are given monthly revenue data for a small company. Your task is to analyse and visualise the data properly.
#
# ### Given Data
#
# ```python
# monthly_revenue = {
#     "Jan": 12000,
#     "Feb": 13500,
#     "Mar": 15000,
#     "Apr": 9000,
#     "May": 20000,
#     "Jun": 17500
# }
# ```
# ## Tasks
#
# ### **Part A (Analysis Function)**
# Create `analyse_revenue(data)` function that does the following:
# 1. Compute total revenue.
# 2. Compute average monthly revenue.
# 3. Identify the best-performing month.
# 4. Identify the worst-performing month.
# 5. Print results clearly and professionally.
#
# ### **Part B (Visualisation Function)**
# Create `plot_revenue(data)` function that does the following:
# 1. Create a **line plot** of monthly revenue.
# 2. Add:
# - Title
# - X-axis label
# - Y-axis label
#
# 3. Display the plot.
#
# ### **Part C (Bar Comparison)**
# Create `plot_bar_comparison(data)` as a second visualisation function that does the following:
# 1. Create a **bar chart**.
#
# 2. Clearly show differences between months.
#
# 3. Ensure revenus for each months are readable (value labels are on the top of each bar, have look at these [examples](https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_label_demo.html))
#
# ### **Part D (Clean Code Requirement)**
# - Use meaningful function names.
# - Avoid duplicated logic.
# - All execution must happen inside:
#  ```python
#  if __name__ == "__main__":
#     main()
# ```
# ---

# %% [markdown]
# ## **Problem 2 (JSON Data Management System)**
# ## Scenario
# You are managing employee salary records and need to store them in JSON format.
#
# ### Create Employee Data
#
# ```python
# employees = [
#     {"name": "Alice",   "department": "IT",      "salary": 4000},
#     {"name": "Bob",     "department": "HR",      "salary": 3500},
#     {"name": "Charlie", "department": "IT",      "salary": 4200},
#     {"name": "Diana",   "department": "Finance", "salary": 5000},
#     {"name": "Eve",     "department": "HR",      "salary": 3800},
#     {"name": "Frank",   "department": "Finance", "salary": 4800},
#     {"name": "Grace",   "department": "IT",      "salary": 3900},
#     {"name": "Hank",    "department": "HR",      "salary": 3200},
#     {"name": "Ivy",     "department": "Finance", "salary": 5200},
#     {"name": "Jack",    "department": "IT",      "salary": 4500},
# ]
# ```
# ## Tasks
#
# ### **Part A (Save to JSON)**
# Create `save_to_json(data, filename)` function that does the following:
# 1. Save data to a JSON file.
# 2. Use indentation for readability.
# 3. Prints a confirmation message after you save the JSON file.
#
#
# ### **Part A (Save to JSON)**
# Create `save_to_json(data, filename)` function that does the following:
# 1. Save data to a JSON file.
# 2. Use indentation for readability.
# 3. Prints a confirmation message after you save the JSON file.
#
# ### **Part B (Load from JSON)**
# Create `load_from_json(filename)` function that does the following:
# 1. Read the file.
# 2. Return the loaded data.
#
# ### **Part C (Data Analysis)**
# Create an `analyse_salaries(data)` function that computes and prints:
# 1. **Total** salary expense
# 2. **Average** salary
# 3. **Highest-paid** employee
# 4. **Employee count** per department
#
# > **Hint 1:** Use Python's built-in `sum()` and `max()` with a key argument.
# > **Hint 2:** Build a dictionary to count employees per department using `.get(key, 0) + 1`.
#
# ### **Part D (Pie Chart: Department Salary Share)**
# Create a `plot_pie_chart(data)` function that shows each department's **total salary** as a share of overall payroll. First, have a look at these [examples](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html).
#
# ### Requirements
# - One slice per department
# - Show percentage labels on each slice using `autopct`
# - Include a legend
# - Title: `"Salary Share by Department"`
# - Save as `salary_pie.png`
#
# ### Hints
#
# **Hint 1: Build department totals:**
# ```python
# dept_totals = {}
# for emp in data:
#     dept = emp["department"]
#     dept_totals[dept] = dept_totals.get(dept, 0) + emp["salary"]
#
# labels = list(dept_totals.keys())
# values = list(dept_totals.values())
# ```
#
# **Hint 2: `autopct` for percentages:**
# Pass `autopct="%1.1f%%"` to show one decimal place on each slice, e.g. `38.5%`.
#
# **Hint 3: `startangle` for a cleaner look:**
# Use `startangle=90` to rotate the first slice to the 12 o'clock position.
#
# **Hint 4: Explode slices (optional):**
# ```python
# explode = [0.05] * len(labels)   # slightly separate every slice
# ax.pie(values, labels=labels, autopct="%1.1f%%", explode=explode)
# ```
#
# ### **Run Everything Together:**
# Once all parts are complete, run this cell to execute the full pipeline from scratch.
#
# **Full pipeline**
# ```python
# print("--- Saving data ---")
# save_to_json(employees, "employees.json")
#
# print("\n--- Loading data ---")
# data = load_from_json("employees.json")
#
# print("\n--- Analysing salaries ---")
# analyse_salaries(data)
#
# print("\n--- Pie Chart ---")
# plot_pie_chart(data)
# ```
# ---

# %% [markdown]
# ## **Problem 3 (API Interaction and Data Processing)**
#
# ## Scenario
# You will retrieve data from a public API and analyse it.
#
# Use:
#
# ```python
# https://huggingface.co/
# ```
# ## Tasks
#
# ### **Part A (API Request)**
# Create `fetch_api_data(url)` function that does the following:
# 1. Send a GET request.
# 2. Check the status code.
# 3. Return JSON data.
# 4. Print an error message if the request fails via Error Handling ( `try` and `except`)
#
# ### **Part B (Inspect Structure)**
# Create `inspect_data(data)` function that does the following:
# 1. Print available keys.
# 2. Print the data type of each key’s value.
# ---

# %% [markdown]
# ### That was TOUGH! Now we are done with the exercises of week 7 🎉🎉🎉 ##
# ![Week 7](luck.png)
