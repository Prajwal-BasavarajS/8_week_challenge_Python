# %% [markdown]
# # Week (6) Exercises
# > **Modular Code Requirement:** Every exercise must be solved using functions. No logic should live at the top level of your script. Each task maps to one well-named function. A `main()` function must call them all.
#
# ### General Modular Code Rules (Apply to All Parts)
#
# | Rule | Requirement |
# |------|-------------|
# | **No top-level logic** | All executable code must be inside functions |
# | **Single responsibility** | Each function does exactly one thing |
# | **Named parameters** | Pass data as arguments; never hardcode inside functions |
# | **`main()` entry point** | All functions are called from `main()` at the bottom |
# | **Guard clause** | End every script with `if __name__ == "__main__": main()` |
# | **Descriptive names** | Function names must describe what they do (`calculate_profit`, not `func1`) |
#
# ```python
# # Required structure for every exercise submission
# def main():
#     # call your functions here
#     pass
#
# if __name__ == "__main__":
#     main()
# ```
# ---

# %% [markdown]
# ## Part (1) NumPy: Vectorised Operations, Element-wise Operations, Scalar Operations & Broadcasting
#
# ### Scenario
# You are a data analyst at a retail chain with seven branches. Each branch has reported its weekly sales figures (in £). Your manager wants a performance summary, a price adjustment report, and a cross-branch comparison. All computed **without** a single `for` loop.
#
# **Sales data (£):**
# ```python
# import numpy as np
# sales = np.array([1200, 850, 960, 1100, 750, 1300, 980])
# costs = np.array([600, 500, 480, 700, 400, 620, 510])
# ```
#
# ### Tasks
#
# **Task 1.1: Sales Summary**
# Write a function `summarise_sales(sales)` that returns a dictionary containing the total, mean, maximum, minimum, and standard deviation of the sales array.
#
# **Task 1.2: Profit Calculation**
# Write a function `calculate_profit(sales, costs)` that returns a new NumPy array of profit per branch (element-wise subtraction).
#
# **Task 1.3: Apply VAT**
# Write a function `apply_vat(sales, vat_rate)` that uses a scalar operation to return a new array with VAT added to each branch's sales. Use a VAT rate of 20%.
#
# **Task 1.4: Normalise Sales**
# Write a function `normalise(arr)` that uses broadcasting to scale every value in the array to a 0–1 range using the formula: `(x - min) / (max - min)`. Return the resulting array.
#
# **Task 1.5: Regional Adjustment**
# You have a regional multiplier for each branch:
# ```python
# multipliers = np.array([1.05, 1.0, 1.1, 1.0, 1.15, 1.05, 1.0])
# ```
# Write a function `apply_regional_multipliers(sales, multipliers)` that returns the adjusted sales using element-wise multiplication.
#
# **Task 1.6: Generate Forecast Periods**
# Write a function `generate_weekly_periods(num_weeks)` that uses `np.arange()` to return an array of week numbers starting from 1 (e.g., `[1, 2, 3, ..., num_weeks]`). Write a second function `generate_growth_targets(start, end, num_points)` that uses `np.linspace()` to return evenly spaced sales targets between a start and end value. Call both with sensible values and print the results.
#
# **Task 1.7: Revenue Matrix**
# You have two 2×3 matrices representing revenue (in £hundreds) across two quarters and three product lines:
# ```python
# Q1 = np.array([[12, 18, 9],
#                [15, 11, 20]])
#
# Q2 = np.array([[14, 16, 10],
#                [13, 19, 17]])
# ```
# Write a function `half_year_revenue(q1, q2)` that uses the dot product (`@` operator) to compute the matrix product of `Q1` and `Q2.T` (transpose of Q2). Write a second function `transpose_matrix(matrix)` that returns the transpose of any given matrix. Print both results with a label explaining what each output represents.
#
# ### Instructions
# - All functions must accept arrays as parameters (no hardcoded data inside functions).
# - Use NumPy vectorised operations only (no Python loops).
# - Print results clearly with labels from a `main()` function.
# - Expected output for `summarise_sales`: a printed dictionary with all five statistics rounded to 2 decimal places.
# - `generate_growth_targets` must use `np.linspace()` not `np.arange()` (Since the targets are evenly spaced floats).
#
# ---

# %% [markdown]
# ## Part (2): Boolean Indexing, Set Operations, Flattening & Reshaping
#
# ### Scenario
# A university stores module enrolment data across two campuses as 2D NumPy arrays. Each value is a student ID. The academic office needs to identify which students are enrolled on both campuses, which are **unique** to each, and needs the data in a flat format for export.
#
# **Campus data:**
# ```python
# campus_a = np.array([[1021, 1034, 1057],
#                      [1082, 1091, 1034]])
#
# campus_b = np.array([[1057, 1100, 1110],
#                      [1034, 1082, 1120]])
#
# scores = np.array([45, 78, 55, 90, 38, 82, 61, 74])
# ```
#
# ### Tasks
#
# **Task 2.1: Filter High Scorers**
# Write a function `filter_scores(scores, threshold)` that uses boolean indexing to return only the scores above the given threshold. Call it with a threshold of 60.
#
# **Task 2.2: Label Performance**
# Write a function `label_performance(scores, pass_mark)` that uses `np.where()` to return an array labelling each score as `"Pass"` or `"Fail"` based on the pass mark.
#
# **Task 2.3: Cross-Campus Enrolment**
# Write three functions:
# - `shared_students(a, b)` : returns students enrolled at both campuses (intersection).
# - `only_campus_a(a, b)`:  returns students only in campus A (set difference).
# - `all_students(a, b)`:  returns all unique student IDs across both campuses (union).
#
# Each function must flatten the 2D arrays internally before performing the set operation.
#
# **Task 2.4: Reshape for Export**
# Write a function `reshape_for_export(arr, rows, cols)` that reshapes a flat 1D array into a 2D array of shape `(rows, cols)`. It should raise a clear `ValueError` with a helpful message if the reshape is not possible.
#
# **Task 2.5: Multi-Condition Filtering**
# Using the `scores` array, write a function `filter_score_range(scores, low, high)` that uses a combined boolean condition (`&`) to return only scores that fall strictly between `low` and `high` (exclusive). Call it to find scores between 50 and 80.
#
# **Task 2.6: Split and Sort**
# Write a function `split_scores(scores, num_groups)` that uses `np.array_split()` to divide the scores array into `num_groups` equal (or near-equal) parts and returns the list of sub-arrays. Write a second function `sort_scores(scores)` that uses `np.sort()` to return the scores in ascending order. Call both from `main()` and print the results.
#
# ### Instructions
# - Flatten 2D arrays inside the function, never assume the input is already flat.
# - `reshape_for_export` must use a `try/except` block to handle invalid shapes gracefully.
# - All set operation functions must work correctly on both 1D and 2D input.
# - `filter_score_range` must use a single combined boolean expression with `&` and no nested `if` statements.
# - `split_scores` and `sort_scores` must not modify the original array and return new arrays.
# - Call all functions from `main()` and print labelled results.
#
# ---

# %% [markdown]
# ## Part (3): Pandas Series & DataFrame
#
# ### Scenario
# You are building a student records system for a small college. You will construct the data using a Pandas Series and a DataFrame, inspect it, add derived columns, and query specific records.
#
# **Raw data:**
# ```python
# import pandas as pd
#
# monthly_library_visits = [45, 60, 30, 80, 55, 70]
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# student_records = {
#     "name":       ["Aisha", "Ben", "Cleo", "Dante", "Elina"],
#     "age":        [20, 22, 21, 23, 20],
#     "grade":      [72, 45, 88, 55, 91],
#     "attendance": [95, 70, 88, 60, 98]
# }
# ```
#
# ### Tasks
#
# **Task 3.1: Build & Summarise a Series**
# Write a function `build_visit_series(visits, index)` that creates and returns a labelled Pandas Series. Write a second function `summarise_series(series)` that prints the total, average, and the month with the highest visits using `idxmax()`.
#
# **Task 3.2: Filter a Series**
# Write a function `filter_series(series, threshold)` that returns only the entries where visits exceed the threshold. Call it with a threshold of 50.
#
# **Task 3.3: Build a DataFrame**
# Write a function `build_student_df(data, index_labels)` that creates and returns a DataFrame with named row indexes (`"student1"` through `"student5"`).
#
# **Task 3.4: Inspect the DataFrame**
# Write a function `inspect_df(df)` that prints:
# - The first 3 rows (`head`)
# - General info (`info`)
# - Descriptive statistics (`describe`)
#
# **Task 3.5: Add a Derived Column & Filter**
# Write a function `add_pass_column(df, pass_mark)` that adds a boolean column `"passed"` and returns the modified DataFrame. Write a second function `get_passing_students(df)` that returns only the rows where `"passed"` is `True`.
#
# **Task 3.6: Locate Specific Records**
# Write a function `get_student_by_label(df, label)` that retrieves and returns a row by its named index label (e.g., `"student3"`).
#
# **Task 3.7: Inspect Head and Tail**
# Write a function `inspect_head_tail(df, n)` that prints the first `n` rows using `df.head(n)` and the last `n` rows using `df.tail(n)` with a clear label for each. Call it with `n=2`.
#
# **Task 3.8: Merge Two DataFrames**
# You have a second batch of student records to add:
# ```python
# new_students = {
#     "name":       ["Finn", "Grace"],
#     "age":        [21, 22],
#     "grade":      [63, 77],
#     "attendance": [88, 91]
# }
# ```
# Write a function `merge_student_records(df1, df2)` that uses `pd.concat()` to combine both DataFrames, resets the index, and returns the merged result. The function must not mutate either input DataFrame.
#
# **Task 3.9: Load from CSV**
# Write a function `load_student_csv(filepath)` that uses `pd.read_csv()` to load a CSV file and returns the resulting DataFrame. Write a second function `preview_csv(df, n)` that prints the first `n` rows and last `n` rows of the loaded data. In `main()`, call `load_student_csv` with a filepath of your choice and pass the result to `preview_csv`. *(Note: you do not need a real file to write these functions, focus on the correct use of `pd.read_csv()` and `df.head()` / `df.tail()`.)*
#
# ### Instructions
# - No DataFrame should be constructed inside `main()` (all creation logic lives in dedicated functions).
# - `inspect_df` must call all three inspection methods in sequence.
# - `add_pass_column` must not mutate the original DataFrame, work on a copy.
# - `merge_student_records` must use `pd.concat()` with `ignore_index=True` to produce a clean integer index.
# - `load_student_csv` must only contain the loading logic; previewing is handled separately by `preview_csv`.
# - All functions must be called and their results printed from `main()`.
#
# ---

# %% [markdown]
# ## Part (4): Grouping, Aggregation & Descriptive Statistics
#
# ### Scenario
# You work in the HR department of a company. You have employee records across three departments. Leadership wants a breakdown of salary statistics per department, an overall salary report, and a count of employees per department.
#
# **Employee data:**
# ```python
# employee_data = {
#     "name":       ["Alice", "Bob", "Carol", "Dan", "Eve", "Frank", "Grace"],
#     "department": ["Engineering", "HR", "Engineering", "Finance", "HR", "Engineering", "Finance"],
#     "salary":     [5200, 3800, 4900, 4100, 3600, 5500, 4300],
#     "years":      [3, 1, 5, 2, 4, 6, 3]
# }
# ```
#
# ### Tasks
#
# **Task 4.1: Group by Department**
# Write a function `average_salary_by_dept(df)` that groups by `"department"` and returns the mean salary for each group.
#
# **Task 4.2: Multiple Aggregations**
# Write a function `dept_salary_stats(df)` that groups by department and returns a summary DataFrame with columns for `min`, `max`, `mean`, and `count` of salaries. Use `.agg()`.
#
# **Task 4.3: Overall Descriptive Statistics**
# Write a function `overall_salary_stats(df)` that prints the mean, median, and standard deviation of the salary column across the entire company.
#
# **Task 4.4: Senior Employees per Department**
# Write a function `senior_employees(df, min_years)` that filters for employees with `years >= min_years`, then groups by department and counts how many senior employees each department has. Call it with `min_years=3`.
#
# **Task 4.5: Top Earner per Department**
# Write a function `top_earner_per_dept(df)` that returns the name and salary of the highest-paid employee in each department.
#
# ### Instructions
# - Every aggregation must live inside its own function. Do not chain groupby + agg in `main()`.
# - `dept_salary_stats` must use `.agg()` with a dictionary of named aggregations.
# - `top_earner_per_dept` must use `groupby` combined with `idxmax()` or equivalent to avoid loops.
# - Print all results from `main()` with clear section headers.
#
# ---

# %% [markdown]
# ## Part (5): Data Cleaning
#
# ### Scenario
# You have received a messy dataset of product sales from a supplier. It contains missing values, duplicate rows, incorrectly formatted prices, and inconsistent category labels. Your job is to write a cleaning pipeline made entirely of modular functions, so each step can be tested and reused independently.
#
# **Messy data:**
# ```python
# import pandas as pd
# import numpy as np
#
# raw_data = {
#     "product":  ["Widget A", "Widget B", "Widget A", "Gadget X", "Gadget X", "Widget B", "Gizmo Z"],
#     "category": ["electronics", "Electronics", "Electronics", "GADGETS", "gadgets", "electronics", None],
#     "price":    ["£12.50", "£8.99", "£12.50", "£24.00", "£24.00", "£8,99", None],
#     "units_sold": [30, None, 30, 15, 15, 22, 10]
# }
# ```
#
# ### Tasks
#
# **Task 5.1: Detect Missing Values**
# Write a function `report_missing(df)` that prints the number of missing values per column and the total number of rows with at least one missing value.
#
# **Task 5.2: Fill Missing Numeric Values**
# Write a function `fill_missing_numeric(df, column)` that fills `NaN` values in the specified numeric column with the column's mean. Return the modified DataFrame.
#
# **Task 5.3: Drop Rows with Missing Categoricals**
# Write a function `drop_missing_categorical(df, column)` that drops all rows where the specified column is `NaN` or empty. Return the cleaned DataFrame.
#
# **Task 5.4: Remove Duplicates**
# Write a function `remove_duplicates(df)` that removes duplicate rows and prints how many duplicates were removed. Return the deduplicated DataFrame.
#
# **Task 5.5: Standardise Category Labels**
# Write a function `standardise_labels(df, column)` that converts all values in the specified column to title case (e.g., `"electronics"` → `"Electronics"`). Return the modified DataFrame.
#
# **Task 5.6: Clean Price Column**
# Write a function `clean_price(df, column)` that:
# 1. Removes the `£` symbol.
# 2. Removes commas (to handle malformed entries like `"£8,99"`).
# 3. Strips whitespace.
# 4. Converts the column to `float`.
#
# Return the modified DataFrame.
#
# **Task 5.7: Full Cleaning Pipeline**
# Write a function `clean_pipeline(df)` that calls the above functions in the correct order and returns the fully cleaned DataFrame. This function should not contain any cleaning logic itself — it only orchestrates the other functions.
#
# ### Instructions
# - `clean_pipeline` must call each individual cleaning function — no cleaning logic inside it.
# - Each function must work on a copy of the DataFrame (use `.copy()`) to avoid mutating the input.
# - `report_missing` is the only function that prints; all others return DataFrames.
# - Call `clean_pipeline` from `main()` and print the final cleaned DataFrame.
# ---

# %% [markdown]
# # Take-Home Assignment
# Complete the following mini challenge at home. Remember to split your screen and solve the challenge step by step. You may always Google, check the syntax, resolve errors, and brainstorm, but **do not generate code or answers**. **Read the full Mini Challenge till the end then start working accordingly**. See the [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md).
#
# ## **Mini Challenge: Smart City Traffic Analysis**
#
# ### **Scenario:**
# A smart city monitoring system collects traffic data from road sensors installed across multiple districts. Each sensor records daily traffic activity, including vehicle counts, average vehicle speeds, congestion levels, weather conditions, and reported accidents.
#
# The transportation department would like to analyse the traffic conditions across the city to identify heavily congested areas and understand general traffic patterns. However, the dataset contains several issues caused by faulty sensors and inconsistent reporting, including:
#
# - missing values,
# - duplicated records,
# - invalid numerical values,
# - inconsistent text formatting.
#
# Your task is to use **NumPy and pandas** to inspect, clean, analyse, and summarise the dataset.
#
# ### **Provided Dataset**
#
# The dataset is stored in a CSV file named:
#
# ```python
# traffic_data.csv
# ```
#
# ### **Example of the Dataset Structure**
#
# | sensor_id | district | vehicle_count | average_speed | congestion_level | weather | accidents |
# |---|---|---|---|---|---|---|
# | S101 | Central | 1450 | 32.5 | 78 | Rainy | 2 |
# | S102 | North | 980 | 48.2 | 40 | Cloudy | 0 |
# | S103 | East | NaN | 25.0 | 88 | Rainy | 1 |
# | S104 | West | -120 | 52.1 | 20 | Sunny | 0 |
# | S105 | Central | 1700 | 18.4 | 95 | Rainy | 3 |
# | S105 | Central | 1700 | 18.4 | 95 | Rainy | 3 |
# | S106 | South | 1250 | -5 | 60 | Sunny | 0 |
# | S107 | East | 890 | 41.7 | 120 | Cloudy | 1 |
#
# and many more (have a look at [`traffic_data.csv`](traffic_data.csv))
#
# ### **Column Description**
#
# | Column Name | Description |
# |---|---|
# | `sensor_id` | Unique identifier of the traffic sensor |
# | `district` | District where the sensor is located |
# | `vehicle_count` | Number of vehicles recorded during the day |
# | `average_speed` | Average vehicle speed in km/h |
# | `congestion_level` | Traffic congestion percentage (0 to 100) |
# | `weather` | Weather condition during data collection |
# | `accidents` | Number of accidents reported |
#
#
# ### **Important observations about the Dataset**
#
# The dataset intentionally contains problems that must be identified and handled during the analysis process.
#
# Examples include:
# - missing values (`NaN`),
# - duplicated rows,
# - negative vehicle counts,
# - negative speed values,
# - congestion levels greater than 100,
# - inconsistent or noisy data.
#
#
# ## Tasks
#
# ### **Task 1: Load and Inspect the Dataset**
#
# #### Requirements
#
# 1. Import NumPy and pandas.
# 2. Load the dataset using pandas.
# 3. Display:
#    - the first five rows,
#    - the last five rows,
#    - dataset dimensions,
#    - column names,
#    - data types.
# 4. Determine:
#    - whether missing values exist,
#    - how many missing values exist per column.
#
# #### Expected Concepts
#
# - `pd.read_csv()`
# - `.head()`
# - `.tail()`
# - `.shape`
# - `.columns`
# - `.dtypes`
# - `.isnull()`
# - `.sum()`
#
# ---
#
# ### **Task 2: NumPy Array Operations**
#
# #### Requirements
#
# 1. Convert:
#    - `vehicle_count`,
#    - `average_speed`
#
#    into NumPy arrays.
#
# 2. Using NumPy operations:
#    - calculate the mean vehicle count,
#    - calculate the maximum and minimum speed,
#    - determine how many roads exceed the average traffic volume.
#
# 3. Apply a vectorized operation:
#    - increase all vehicle counts by 10% to simulate peak-hour traffic.
#
# 4. Display the updated values.
#
# #### Expected Concepts
#
# - `.to_numpy()`
# - `np.mean()`
# - `np.max()`
# - `np.min()`
# - Boolean masking
# - Vectorized arithmetic operations
#
# ---
#
# ### **Task 3: Data Selection and Filtering**
#
# #### Requirements
#
# 1. Create a smaller DataFrame containing only:
#    - `sensor_id`,
#    - `district`,
#    - `vehicle_count`,
#    - `average_speed`.
#
# 2. Filter:
#    - roads with congestion levels above 70,
#    - roads with average speeds below 30 km/h,
#    - all records from the `Central` district.
#
# 3. Display the filtered results clearly.
#
# #### Expected Concepts
#
# - Column selection
# - Boolean filtering
# - Conditional queries
#
# ---
#
# ### **Task 4: Aggregation and Descriptive Statistics**
#
# #### Requirements
#
# 1. Group the dataset by district.
# 2. Calculate:
#    - average vehicle count,
#    - average congestion level,
#    - total accidents per district.
#
# 3. Generate descriptive statistics for numerical columns.
#
# 4. Identify:
#    - the district with the highest average congestion,
#    - the district with the lowest average speed.
#
# #### Expected Concepts
#
# - `.groupby()`
# - `.mean()`
# - `.sum()`
# - `.describe()`
# - Aggregation functions
#
# ---
#
# ### **Task 5: Data Cleaning**
#
# #### Requirements
#
# 1. Detect missing values.
# 2. Handle missing values appropriately.
# 3. Remove duplicated rows.
# 4. Identify invalid records:
#    - negative vehicle counts,
#    - speeds below 0,
#    - congestion levels outside 0 to 100.
# 5. Remove invalid values.
# 6. Standardise text formatting if necessary.
#
# #### Expected Concepts
#
# - `.drop_duplicates()`
# - `.fillna()`
# - `.dropna()`
# - Conditional replacement
# - Data validation
#
# ---
#
# ### **Task 6: Final Analysis Summary**
#
# **Write a short summary discussing:**
# - which districts appear to have the heaviest traffic,
# - whether congestion affects vehicle speed,
# - possible reasons for invalid traffic data,
# - why data cleaning is essential before performing analysis.
#
# The summary should be written in clear technical language **in your words**.
#
# ---
#
# ### **Additional Instructions**
#
# - Use both NumPy and pandas throughout the mini challenge.
# - Organise your answer into clearly labelled comments based on each task.
# - Add comments explaining important operations.
# - Use meaningful variable names.
# - Ensure that all your answers in a **modular code**.
# - Maintain readable output formatting.
# - Preserve the original dataset by **creating a cleaned copy**.
# - Save the **cleaned dataset** as:
#
# ```python
# cleaned_traffic_data.csv
# ```
#
# ---
#
# ### **Suggested Answer Structure (Optional)**
#
# ```python
# 1. Import Libraries
# 2. Load Dataset
# 3. Initial Inspection
# 4. NumPy Operations
# 5. Data Filtering
# 6. Aggregation and Statistics
# 7. Data Cleaning
# 8. Final Analysis Summary
# 9. Export Cleaned Dataset
# ```
#
# ---

# %% [markdown]
# ### Well done, Week 6 Exercises Complete 🎉!
#
# - Don't forget to submit your [exercise notebook](Week6_Exercise.ipynb) on your private GitHub Repository (see [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md)). The deadline is 27.05.2026 @ 23:59.
#
# - See you next time when we dive into `Data Visualization, APIs & Clean Code`!
